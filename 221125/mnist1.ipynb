# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
cd /content/drive/MyDrive/Mia-Github/Colabs/Git-Basic-Pytorch/Basic-Pytorch/221125
# Out:
# /content/drive/MyDrive/Mia-Github/Colabs/Git-Basic-Pytorch/Basic-Pytorch/221125

# %%
cd /content/drive/MyDrive/WegraLee
# Out:
# /content/drive/MyDrive/WegraLee

# %%
# !git clone https://github.com/kchcoo/WegraLee-deep-learning-from-scratch.git
# Out:
# Cloning into 'WegraLee-deep-learning-from-scratch'...
# remote: Enumerating objects: 756, done.
# remote: Total 756 (delta 0), reused 0 (delta 0), pack-reused 756
# Receiving objects: 100% (756/756), 51.77 MiB | 17.21 MiB/s, done.
# Resolving deltas: 100% (465/465), done.

# %%
import sys, os
sys.path.append(os.pardir)
from dataset.mnist import load_mnist

# %%
(x_train, y_train), (x_test, y_test) = load_mnist(flatten=True, normalize=False)
# Out:
# Converting train-images-idx3-ubyte.gz to NumPy Array ...
# Done
# Converting train-labels-idx1-ubyte.gz to NumPy Array ...
# Done
# Converting t10k-images-idx3-ubyte.gz to NumPy Array ...
# Done
# Converting t10k-labels-idx1-ubyte.gz to NumPy Array ...
# Done
# Creating pickle file ...
# Done!

# %%
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (60000, 784)
# (60000,)
# (10000, 784)
# (10000,)
